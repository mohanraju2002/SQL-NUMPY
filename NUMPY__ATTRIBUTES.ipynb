# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanraju2002/SQL-Server-Management-Studio-21/blob/master/NUMPY__ATTRIBUTES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ---------------------------------------------------  Numpy Array Attributes  -----------------------------------------------------------
# 1. shape attribute
# 2. ndim attribute
# 3. arrayobject.T

# -------------------------------------SHAPE ATTRIBUTE-------------------------------------------
#  shape is a predefined attribute in numpy array.
#  shape attribute is used to the to find the number of row and no of coloums in the array
#  Shape attribute returns the tuple as number of rows and columns.
print("############################### SHAPE ATTRIBUTE ########################################")

import numpy as np
a=([2,3,4,5],[4,3,2,4])
b=np.array(a)
print(b)
print()
print(b.shape)

print("----------------------------------------------------------------------------------------")

import numpy as np
a=([34,3],[44,55])
b=np.array(a)
print(b)
print()
print(b.shape)

print("----------------------------------------------------------------------------------------")

import numpy as np
a=([34,3],[44,55],[56,89],[55,90])
b=np.array(a)
print(b)
print()
print(b.shape)


#------------------------------------- NDIM.ATTRIBUTE ------------------------------------------

#  ndim is a predefined attribute in numpy array.
#  We should access this ndim attribute by using numpy array object
#  By using this we can check the dimensions of an array
print("############################### NDIM. ATTRIBUTE ########################################")

import numpy as np
a=([34,3,44,55,56,89,55,90])
b=np.array(a)                            # 1 dimensional
print(b)
print()
print(b.ndim)


print("----------------------------------------------------------------------------------------")

import numpy as np
a=([34,3,44,55],[56,89,55,90])
b=np.array(a)                             # 2 dimensional
print(b)
print()
print(b.ndim)

print("----------------------------------------------------------------------------------------")

import numpy as np
a=([34,3],[44,55],[56,89],[55,90])
b=np.array(a)                              # 2 dimensional
print(b)
print()
print(b.ndim)
 # -----------------------------------  ARRATOBJECT.T ----------------------------------------
#  T is a predefined attribute in numpy array.
#  it is used to convert the rown into coloums and columns into rows

print("###############################  ARRAYOBJECT.T ########################################")

import numpy as np
a=([[22,33,44,55],[11,55,88,99]])
b=np.array(a)
print(b)
print()
print(b.T)

print("----------------------------------------------------------------------------------------")

import numpy as np
a=([[22,33,44,55],[11,55,88,99]])
b=np.array(a)
print(b)
print(b.shape)
print()
c=b.T
print(c)
print(c.shape)


print("-----------------------------------------------------------------------------")

import numpy as np
a=([[22,33],[44,55],[11,55],[88,99]])
b=np.array(a)
print(b)
print()
print(b.T)
